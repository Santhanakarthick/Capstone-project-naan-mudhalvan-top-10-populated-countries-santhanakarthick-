# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # 🗺️Top_10_Populated_countries_1955to2050 Visualization

# %% [markdown]
# ![Add a heading.png](attachment:aa6ebbed-e01f-4837-ba36-d436f5631075.png)

# %% [markdown]
# # Import Libraries:

# %%
import pandas as pd 
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt
import plotly as px
import plotly.graph_objects as go
import sys
print("Python version:", sys.version)
# Out:
# Python version: 3.12.2 (tags/v3.12.2:6abddd9, Feb  6 2024, 21:26:36) [MSC v.1937 64 bit (AMD64)]

# %% [markdown]
# # Load dataset:

# %%
#here we read our csv file 
df = pd.read_csv('Top_10_Populated_countries_1955to2050_forcasted.csv')
df.head()
# Out:
#    year       india       china        USA  Indonesia   Pakistan    Nigeria  \
# 0  2050  1670490596  1312636325  375391963  317225213  367808468  377459883
# 1  2045  1645863187  1349756901  371715154  313666981  345818945  349603702
# 2  2040  1611676333  1377556938  366616240  308164809  322595767  320779660
# 3  2035  1567802259  1399547500  360016420  300882677  298432780  291591598
# 4  2030  1514994080  1415605906  352162301  292150100  274029836  262580426
#
#       brazil  Bangladesh     Russia     Mexico
# 0  230885725   203904900  133133035  143772364
# 1  231122502   200709378  135171274  142919109
# 2  230132293   196526123  137110991  141055171
# 3  227705396   191166614  139227987  138200922
# 4  223908968   184424144  141432741  134534107

# %% [markdown]
# ## Print dataset:

# %%
# here we print and see our dataset
df
# Out:
#     year       india       china        USA  Indonesia   Pakistan    Nigeria  \
# 0   2050  1670490596  1312636325  375391963  317225213  367808468  377459883
# 1   2045  1645863187  1349756901  371715154  313666981  345818945  349603702
# 2   2040  1611676333  1377556938  366616240  308164809  322595767  320779660
# 3   2035  1567802259  1399547500  360016420  300882677  298432780  291591598
# 4   2030  1514994080  1415605906  352162301  292150100  274029836  262580426
# 5   2025  1454606724  1424381924  343603404  282004306  249948885  234573603
# 6   2024  1441719852  1425178782  341814420  279798049  245209815  229152217
# 7   2023  1428627663  1425671352  339996563  277534122  240485658  223804632
# 8   2022  1417173173  1425887337  338289857  275501339  235824862  218541212
# 9   2020  1396387127  1424929781  335942003  271857970  227196741  208327405
# 10  2015  1322866505  1393715448  324607776  259091970  210969298  183995785
# ...

# %% [markdown]
# ## data information:

# %%
# check info of the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        23 non-null     int64
#  1   india       23 non-null     int64
#  2   china       23 non-null     int64
#  3   USA         23 non-null     int64
#  4   Indonesia   23 non-null     int64
#  5   Pakistan    23 non-null     int64
#  6   Nigeria     23 non-null     int64
#  7   brazil      23 non-null     int64
#  8   Bangladesh  23 non-null     int64
#  9   Russia      23 non-null     int64
#  10  Mexico      23 non-null     int64
# dtypes: int64(11)
# memory usage: 2.1 KB

# %% [markdown]
# ## Column names:

# %%
# here we gonna check column names
df.columns
# Out:
# Index(['year', 'india', 'china', 'USA', 'Indonesia', 'Pakistan', 'Nigeria',
#        'brazil', 'Bangladesh', 'Russia', 'Mexico'],
#       dtype='object')

# %% [markdown]
# # Sort data by year 1955 to 2050:

# %%
# Sort the DataFrame by the 'year' column in ascending order and save it as a new DataFrame
new_df = df.sort_values('year')

# Print the new DataFrame
new_df
# Out:
#     year       india       china        USA  Indonesia   Pakistan    Nigeria  \
# 22  1955   398577992   603320147  161136449   77741502   41023128   40839223
# 21  1960   445954579   654170692  176188578   88382881   45954226   44928342
# 20  1965   500114346   723846349  189703283  101157868   51841626   49925799
# 19  1970   557501301   822534450  200328340  115228394   59290872   55569264
# 18  1975   623524219   915124661  211274535  131213215   68126999   62851312
# 17  1980   696828385   982372466  223140018  148177096   80624057   72951439
# 16  1985   780242084  1060239979  235146182  165791694   97121552   83585251
# 15  1990   870452165  1153704252  248083732  182159874  115414069   95214257
# 14  1995   964279129  1218144426  265660556  198140162  133117476  108187610
# 13  2000  1059633675  1264099069  282398554  214072421  154369924  122851984
# 12  2005  1154638713  1304887562  296842670  228805144  174372098  140490722
# ...

# %% [markdown]
# ### Forcasted data:

# %%
# Create a new DataFrame containing the data from 2024 to 2050
forcasted_df = df[df['year'].between(2024, 2050)]

# Display the new DataFrame
forcasted_df
# Out:
#    year       india       china        USA  Indonesia   Pakistan    Nigeria  \
# 0  2050  1670490596  1312636325  375391963  317225213  367808468  377459883
# 1  2045  1645863187  1349756901  371715154  313666981  345818945  349603702
# 2  2040  1611676333  1377556938  366616240  308164809  322595767  320779660
# 3  2035  1567802259  1399547500  360016420  300882677  298432780  291591598
# 4  2030  1514994080  1415605906  352162301  292150100  274029836  262580426
# 5  2025  1454606724  1424381924  343603404  282004306  249948885  234573603
# 6  2024  1441719852  1425178782  341814420  279798049  245209815  229152217
#
#       brazil  Bangladesh     Russia     Mexico
# 0  230885725   203904900  133133035  143772364
# 1  231122502   200709378  135171274  142919109
# 2  230132293   196526123  137110991  141055171
# 3  227705396   191166614  139227987  138200922
# 4  223908968   184424144  141432741  134534107
# 5  218803058   176421509  143494210  130301391
# ...

# %% [markdown]
# _____

# %% [markdown]
# #  **Data Visualization:**

# %% [markdown]
# ### Bar chart 2024

# %%
# Filter data for the year 2024
df_2024 = df[df['year'] == 2024]

# Plotting the bar chart for the year 2024 with different colors for each country and text on each bar
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 8))
bars = plt.bar(df_2024.columns[1:], df_2024.values[0][1:], color=['blue', 'red', 'green', 'orange', 'purple', 'brown', 'pink', 'gray', 'cyan', 'magenta'])
plt.xlabel('Country')
plt.ylabel('Population')
plt.title('Population Comparison for the Year 2024')
plt.xticks(rotation=45)
plt.tight_layout()

# Adding text on each bar
for bar, population in zip(bars, df_2024.values[0][1:]):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), f'{population:,}', ha='center', va='bottom')

plt.show()

# %% [markdown]
# ### Bar chart 2050:

# %%
# Filter data for the year 2050
df_2050 = df[df['year'] == 2050]

# Plotting the bar chart for the year 2050 with different colors for each country and text on each bar
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 8))
bars = plt.bar(df_2050.columns[1:], df_2050.values[0][1:], color=['blue', 'red', 'green', 'orange', 'purple', 'brown', 'pink', 'gray', 'cyan', 'magenta'])
plt.xlabel('Country')
plt.ylabel('Population')
plt.title('Population Comparison for the Year 2050')
plt.xticks(rotation=45)
plt.tight_layout()

# Adding text on each bar
for bar, population in zip(bars, df_2050.values[0][1:]):
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), f'{population:,}', ha='center', va='bottom')

plt.show()

# %% [markdown]
# ### Pie Chart 2024:

# %%
# here we use pie chart to see population share of 10 countries

# Filter data for the year 2024
df_2024 = df[df['year'] == 2024]

# Set up colors for the pie chart
colors = ['blue', 'red', 'green', 'orange', 'purple', 'brown', 'pink', 'gray', 'cyan', 'magenta']

# Create the pie chart
plt.figure(figsize=(8, 8))
plt.pie(df_2024.values[0][1:], labels=df_2024.columns[1:], colors=colors, autopct='%1.1f%%')
plt.title('Population Distribution by Country in 2024')
plt.show()

# %% [markdown]
# ### Stack bar chart:

# %%
# here we make stackbar for check population increase in top 10 countries
# Filter data for the years 2024 and 2050
df_2024 = df[df['year'] == 2024]
df_2050 = df[df['year'] == 2050]

# Set up colors for the bars
color_2024 = 'blue'
color_2050 = 'orange'

# Plotting the stacked bar chart
plt.figure(figsize=(12, 8))

# Bar for 2024 population
plt.bar(df_2024.columns[1:], df_2024.values[0][1:], color=color_2024, label='2024')

# Bar for 2050 population stacked on top of 2024 population
plt.bar(df_2050.columns[1:], df_2050.values[0][1:], color=color_2050, bottom=df_2024.values[0][1:], label='2050')

# Annotations for 2024 population
for i, val in enumerate(df_2024.values[0][1:]):
    plt.text(i, val + 0.05 * val, str(val), ha='center', va='bottom')

# Annotations for 2050 population
for i, val in enumerate(df_2050.values[0][1:]):
    plt.text(i, df_2024.values[0][i+1] + val + 0.05 * val, str(val), ha='center', va='bottom')

plt.xlabel('Country')
plt.ylabel('Population')
plt.title('Population Comparison for 2024 and 2050')
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Heat map of 2024 and 2050:

# %%
# here we going to check heatmap of 2024 and 2050

# Filter data for the years 2024 and 2050
df_2024 = df[df['year'] == 2024]
df_2050 = df[df['year'] == 2050]

# Concatenate data for both years
df_combined = pd.concat([df_2024, df_2050])

# Transpose the DataFrame for plotting
df_combined_transposed = df_combined.set_index('year').T

# Plotting the heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(df_combined_transposed, cmap='coolwarm', annot=True, fmt='d')
plt.title('Population Heatmap for 2024 and 2050')
plt.xlabel('Year')
plt.ylabel('Country')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Line chart:

# %%
# here we are goint to make line chart for countries
# Plotting
plt.figure(figsize=(10, 6))
for column in df.columns[1:]:
    plt.plot(df['year'], df[column], marker='o', label=column.capitalize())

plt.title('Population Growth Over Years')
plt.xlabel('Year')
plt.ylabel('Population')
plt.legend()
plt.grid(True)
plt.xticks(df['year'], rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Conclusion

# %% [markdown]
# At the and lets discussion our qurries one by one
#
# 1. Top 10 Countries as of April 30, 2024:
#  - I used the dataset to filter and identify the top 10 countries based on their population as of April 30, 2024.
#
#
# 2. Historical Data since 1955 for the Top 10 Countries:
#  - I retrieved historical population data for the identified top 10 countries from 1955 to April 30, 2024.
#
#
# 3. Forecasted Dataset from 2024 to 2050:
#  - I have Utilized the historical data to forecast population trends for the top 10 countries from 2024 to 2050 using appropriate forecasting techniques.
#
#
# 4. Visualization of the Dataset:
#  - I have created visualizations such as line charts, bar charts, or area charts to illustrate population trends over time for the top 10 countries.
#  - I have ensured the visualizations are clear, labeled appropriately, and provide insights into population growth or decline.

# %% [markdown]
# At the end i wanna thanks to you that you take time to read my notebook.

# %% [markdown]
# #                                                            **THE END**
